# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import sys

print(sys.path)
# Out:
# ['C:\\Users\\Christopher Maringka\\PycharmProjects\\HousePrice', 'C:\\Users\\Christopher Maringka\\anaconda3\\python39.zip', 'C:\\Users\\Christopher Maringka\\anaconda3\\DLLs', 'C:\\Users\\Christopher Maringka\\anaconda3\\lib', 'C:\\Users\\Christopher Maringka\\anaconda3', '', 'C:\\Users\\Christopher Maringka\\anaconda3\\lib\\site-packages', 'C:\\Users\\Christopher Maringka\\anaconda3\\lib\\site-packages\\locket-0.2.1-py3.9.egg', 'C:\\Users\\Christopher Maringka\\anaconda3\\lib\\site-packages\\win32', 'C:\\Users\\Christopher Maringka\\anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Users\\Christopher Maringka\\anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Users\\Christopher Maringka\\anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\Christopher Maringka\\.ipython']

# %%
# Reading the data

# %%
training = pd.read_csv('C:\\Users\\Christopher Maringka\\PycharmProjects\\HousePrice\\data\\train.csv')

# %%
testing = pd.read_csv('C:\\Users\\Christopher Maringka\\PycharmProjects\\HousePrice\\data\\test.csv')

# %%
training['cat_test'] = 1

# %%
testing['cat_test'] = 0

# %%
print(testing)
# Out:
#         Id  MSSubClass                                       SubClassDesc  \
# 0     1461          20                    1-STORY 1946 & NEWER ALL STYLES
# 1     1462          20                    1-STORY 1946 & NEWER ALL STYLES
# 2     1463          60                               2-STORY 1946 & NEWER
# 3     1464          60                               2-STORY 1946 & NEWER
# 4     1465         120  1-STORY PUD (Planned Unit Development) - 1946 ...
# ...    ...         ...                                                ...
# 1454  2915         160                         2-STORY PUD - 1946 & NEWER
# 1455  2916         160                         2-STORY PUD - 1946 & NEWER
# 1456  2917          20                    1-STORY 1946 & NEWER ALL STYLES
# 1457  2918          85                                        SPLIT FOYER
# 1458  2919          60                               2-STORY 1946 & NEWER
#
#      MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour  \
# ...

# %%
testing['SalePrice'] = np.NaN

# %%
df = pd.concat([training,testing])

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 82 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   SubClassDesc   1460 non-null   object
#  3   MSZoning       1460 non-null   object
#  4   LotFrontage    1201 non-null   float64
#  5   LotArea        1460 non-null   int64
#  6   Street         1460 non-null   object
#  7   Alley          91 non-null     object
#  8   LotShape       1460 non-null   object
#  9   LandContour    1460 non-null   object
#  10  Utilities      1460 non-null   object
#  11  LotConfig      1460 non-null   object
#  12  LandSlope      1460 non-null   object
#  13  Neighborhood   1460 non-null   object
#  14  Condition1     1460 non-null   object
#  15  Condition2     1460 non-null   object
#  16  BldgType       1460 non-null   object
# ...

# %%
pd.set_option("display.max_columns", None)

# %%
training.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
## Variable which needs further analysis: Alley, FireplaceQu, PoolQC, Fence,MiscFeature -- too many missing value

# %%
df_num = training.select_dtypes(exclude='object')

# %%
df_cat = training.select_dtypes('object')

# %%
df_num = df_num.drop(columns=['Id', 'MSSubClass'])

# %%
df_num.head(5)
# Out:
#    LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0         65.0     8450            7            5       2003          2003
# 1         80.0     9600            6            8       1976          1976
# 2         68.0    11250            7            5       2001          2002
# 3         60.0     9550            7            5       1915          1970
# 4         84.0    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0       196.0         706           0        150          856       856
# 1         0.0         978           0        284         1262      1262
# 2       162.0         486           0        434          920       920
# 3         0.0         216           0        540          756       961
# 4       350.0         655           0        490         1145      1145
#
#    2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  \
# ...

# %%
for item in df_num.columns:
    plt.hist(df_num[item])
    plt.title(item)
    plt.show()

# %%
df_num.corr(method='pearson', min_periods=1).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_1653d_row0_col0, #T_1653d_row1_col1, #T_1653d_row2_col2, #T_1653d_row3_col3, #T_1653d_row4_col4, #T_1653d_row5_col5, #T_1653d_row6_col6, #T_1653d_row7_col7, #T_1653d_row8_col8, #T_1653d_row9_col9, #T_1653d_row10_col10, #T_1653d_row11_col11, #T_1653d_row12_col12, #T_1653d_row13_col13, #T_1653d_row14_col14, #T_1653d_row15_col15, #T_1653d_row16_col16, #T_1653d_row17_col17, #T_1653d_row18_col18, #T_1653d_row19_col19, #T_1653d_row20_col20, #T_1653d_row21_col21, #T_1653d_row22_col22, #T_1653d_row23_col23, #T_1653d_row24_col24, #T_1653d_row25_col25, #T_1653d_row26_col26, #T_1653d_row27_col27, #T_1653d_row28_col28, #T_1653d_row29_col29, #T_1653d_row30_col30, #T_1653d_row31_col31, #T_1653d_row32_col32, #T_1653d_row33_col33, #T_1653d_row34_col34, #T_1653d_row35_col35 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1653d_row0_col1, #T_1653d_row22_col10, #T_1653d_row26_col4 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# ...

# %%
pd.pivot_table(training, index = 'SubClassDesc', values = 'SalePrice')
# Out:
#                                                         SalePrice
# SubClassDesc
# 1-1/2 STORY - UNFINISHED ALL AGES                   108591.666667
# 1-1/2 STORY FINISHED ALL AGES                       143302.972222
# 1-STORY 1945 & OLDER                                 95829.724638
# 1-STORY 1946 & NEWER ALL STYLES                     185224.811567
# 1-STORY PUD (Planned Unit Development) - 1946 &...  200779.080460
# 1-STORY W/FINISHED ATTIC ALL AGES                   156125.000000
# 2 FAMILY CONVERSION - ALL STYLES AND AGES           129613.333333
# 2-1/2 STORY ALL AGES                                192437.500000
# 2-STORY 1945 & OLDER                                166772.416667
# 2-STORY 1946 & NEWER                                239948.501672
# 2-STORY PUD - 1946 & NEWER                          138647.380952
# DUPLEX - ALL STYLES AND AGES                        133541.076923
# PUD - MULTILEVEL - INCL SPLIT LEV/FOYER             102300.000000
# ...

# %%
training['hasAlley'] = np.where(training['Alley'].isna(), 0, 1)

# %%
training['hasPool'] = np.where(training['PoolQC'].isna(), 0, 1)

# %%
training['HasMiscFeature'] = np.where(training['MiscFeature'].isna(), 0, 1)

# %%
training.head(5)
# Out:
#    Id  MSSubClass                     SubClassDesc MSZoning  LotFrontage  \
# 0   1          60             2-STORY 1946 & NEWER       RL         65.0
# 1   2          20  1-STORY 1946 & NEWER ALL STYLES       RL         80.0
# 2   3          60             2-STORY 1946 & NEWER       RL         68.0
# 3   4          70             2-STORY 1945 & OLDER       RL         60.0
# 4   5          60             2-STORY 1946 & NEWER       RL         84.0
#
#    LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0     8450   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1     9600   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2    11250   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3     9550   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4    14260   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# ...

# %%
## Alley, FireplaceQu, PoolQC, Fence,MiscFeature -- too many missing value. Converting them to has these feature or not may be better

# %%
##
